# %%
import matplotlib.pyplot as plt
plt.plot([1.1,  1,0.2,0.0,0.0,0.2,0.8,1.0,1.0,0.8,0,-.1,0,  1.35,  1.2,1.6,2.01,1.35,2.01,2.2,2.05,  2.55,2.4,  2.4,2.9,3.4,3.4,3.25,  3.8,3.8,3.65,3.95,3.8,3.8,3.95,  4.05,4.15,  4.4,4.2,4.2,4.1,4.3,4.2,4.2,4.4,5,5.2,5.2,5.1,5.3,5.2,5.2,5.0,5.2,  5.30,5.4,  5.5,5.5,5.5,6.3,  6.4],
         [4.2,  4,4.0,3.8,2.2,2.0,2.0,1.8,0.2,0.0,0,-.2,0,  0.00,  0.0,4.0,1.20,1.20,1.20,0.0,0.00,  0.00,0.0,  4.0,2.0,4.0,0.0,0.00,  0.0,4.0,4.00,4.00,4.0,0.0,0.00,  0.10,0.00,  0.0,0.2,4.0,4.0,4.0,4.0,0.2,0.0,0,0.2,4.0,4.0,4.0,4.0,0.2,0.0,0.0,  0.10,0.0,  0.0,4.0,0.0,0.0,  -.2])
#plt.ylabel('SAMIUL Sir')
plt.axis([-0.3, 6.7, -2, 6])
plt.show()
