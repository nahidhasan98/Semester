# %%
import numpy as np

names = np.array(['Bob', 'Joe', 'Will', 'Bob', 'Will', 'Joe', 'Joe'])
data = np.random.randn(7, 4)
names
data

names == 'Bob'

data[names == 'Bob']

arr = np.arange(16).reshape((2, 2, 4))
arr
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-370669a4c9cf> in <module>()
#      10 data[names == 'Bob']
#      11
# ---> 12 arr = np.arange(16).reshape((2, 2, 5))
#      13 arr
#
# ValueError: cannot reshape array of size 16 into shape (2,2,5)
