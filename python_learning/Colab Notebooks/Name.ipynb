# %%
import matplotlib.pyplot as plt
plt.plot([0,0,1,1,1,1,1.5,2,1.85,1.15,1.85,2,2,2,  3,  3,3,3.3,3.3,3.2,3.4,3.3,3.3,3.6,3.6,4.3,4.6,4.3,3.6],
         [0,5,0,5,0,0,5,  0,1.5, 1.5, 1.5, 0,5,2.5,2.5,5,0,0,  5,  5,  5,  5,  0,  0,  5,  4.8,2.5,0.2,0  ])
plt.ylabel('NAHID')
plt.show()
